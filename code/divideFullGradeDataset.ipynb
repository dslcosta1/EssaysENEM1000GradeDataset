# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import ast
import os
import csv

# %%
path_to = '/content/drive/MyDrive/IME/9sem/TCC/dados/'
path_to_experiment_prompts = '/content/drive/MyDrive/IME/9sem/TCC/dados/experimentosPrompts/'

import sys
sys.path.insert(0, path_to)

# %%
df = pd.read_csv(path_to + 'essaysFullGrade.csv')

# %%
df.head()
# Out:
#    id                   author  \
# 0   0              André Bahia
# 1   1  Carolina Mendes Pereira
# 2   2           Clara de Jesus
# 3   3        Fabricio Vitorino
# 4   4       Fernanda C. Santos
#
#                                            id_prompt  essay_year  \
# 0  Manipulação do comportamento do usuário pelo c...        2018
# 1  Manipulação do comportamento do usuário pelo c...        2018
# 2  Manipulação do comportamento do usuário pelo c...        2018
# 3  Manipulação do comportamento do usuário pelo c...        2018
# 4  Manipulação do comportamento do usuário pelo c...        2018
#
#                             grades  \
# 0  [200, 200, 200, 200, 200, 1000]
# 1  [200, 200, 200, 200, 200, 1000]
# 2  [200, 200, 200, 200, 200, 1000]
# 3  [200, 200, 200, 200, 200, 1000]
# 4  [200, 200, 200, 200, 200, 1000]
#
#                                           essay_text  \
# 0  "Segundo Steve Jobs, um dos fundadores da empr...
# ...

# %%
df = df.drop(columns="author_info")

# %%
df.head()
# Out:
#    id                   author  \
# 0   0              André Bahia
# 1   1  Carolina Mendes Pereira
# 2   2           Clara de Jesus
# 3   3        Fabricio Vitorino
# 4   4       Fernanda C. Santos
#
#                                            id_prompt  essay_year  \
# 0  Manipulação do comportamento do usuário pelo c...        2018
# 1  Manipulação do comportamento do usuário pelo c...        2018
# 2  Manipulação do comportamento do usuário pelo c...        2018
# 3  Manipulação do comportamento do usuário pelo c...        2018
# 4  Manipulação do comportamento do usuário pelo c...        2018
#
#                             grades  \
# 0  [200, 200, 200, 200, 200, 1000]
# 1  [200, 200, 200, 200, 200, 1000]
# 2  [200, 200, 200, 200, 200, 1000]
# 3  [200, 200, 200, 200, 200, 1000]
# 4  [200, 200, 200, 200, 200, 1000]
#
#                                           essay_text  \
# 0  "Segundo Steve Jobs, um dos fundadores da empr...
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test = train_test_split(
    df, test_size=0.15, random_state=42)

X_train, X_val = train_test_split(
    X_train, test_size=0.15, random_state=42)

# %%
path_to_dataset = path_to + "FullGradeEnemEssays2024/"

X_train.to_csv(path_to_dataset + 'train.csv', index=False)
X_test.to_csv(path_to_dataset + 'test.csv', index=False)
X_val.to_csv(path_to_dataset + 'validation.csv', index=False)
